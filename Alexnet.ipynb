# %%
from cub2011 import *
from torchvision.models import alexnet, AlexNet_Weights
from torchvision import transforms
import torch.nn as nn
import torch

# Define the transform with augmentation
transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # 随机裁剪并调整大小
    transforms.RandomHorizontalFlip(),                    # 随机水平翻转
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 随机颜色抖动
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Define the transform
# transform = transforms.Compose([
#     transforms.Resize((224, 224)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
# ])

# load dataset
train = Cub2011("", transform=transform)
test = Cub2011("", train=False, transform=transform)

# see example data
# img, target = train.__getitem__(999)
# img.show()

# load alexnet
# net = alexnet(weights=AlexNet_Weights.IMAGENET1K_V1)
net = alexnet(weights=None)
net.classifier[-1] = nn.Linear(4096, 200)

# move the net to GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print(device)
net.to(device)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=200, bias=True)
#   )
# )

# %%
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import StepLR
from torch.utils.tensorboard import SummaryWriter


# Loss
criterion = nn.CrossEntropyLoss()

# Separate parameters into two groups
base_lr = 0.1
finetune_rate = 1
finetune_lr = finetune_rate * base_lr
params_to_update = [
    {'params': net.features.parameters(), 'lr': finetune_lr},  # Base layers
    {'params': net.classifier[:-1].parameters(), 'lr': finetune_lr},  # Classifier layers except the last one
    {'params': net.classifier[-1].parameters(), 'lr': base_lr}  # The last layer
]


# optimizer
optimizer = optim.SGD(params_to_update, momentum=0.9, weight_decay=1e-4)

# Learning rate sechuler
scheduler = StepLR(optimizer, step_size=50, gamma=0.1)

train_loader = DataLoader(train, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test, batch_size=32, shuffle=False, num_workers=4)

# TENSORBOARD
writer = SummaryWriter(log_dir='Alexnet/alexnet-lre-1-randomized')

# training loop
num_epochs = 110
for epoch in range(num_epochs):
    # train
    net.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    train_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.3f}", end=", ")
    
    # Write training loss to TensorBoard
    writer.add_scalar('Training Loss', train_loss, epoch)

    # validation
    net.eval()
    correct = 0
    total = 0
    running_loss = 0.0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to the device
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    val_loss = running_loss / len(test_loader)
    accuracy = 100 * correct / total
    print(f'Validation Loss: {val_loss:.3f}', end=", ")
    print(f'Accuracy on test set: {accuracy:.3f}%')

    # Write validation loss and accuracy to TensorBoard
    writer.add_scalar('Validation Loss', val_loss, epoch)
    writer.add_scalar('Accuracy', accuracy, epoch)

    # Update the learning rate
    scheduler.step()
    
# Close the TensorBoard writer
writer.close()
# Out:
# Epoch 1/110, Training Loss: 5.312, Validation Loss: 5.299, Accuracy on test set: 0.501%
# Epoch 2/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 3/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 4/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 5/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 6/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 7/110, Training Loss: 5.311, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 8/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 9/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 10/110, Training Loss: 5.311, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 11/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.501%
# Epoch 12/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 13/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.190%
# Epoch 14/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 15/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 16/110, Training Loss: 5.311, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 17/110, Training Loss: 5.312, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 18/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 19/110, Training Loss: 5.311, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 20/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 21/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.501%
# Epoch 22/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 23/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 24/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 25/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.501%
# Epoch 26/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 27/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 28/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 29/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 30/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.345%
# Epoch 31/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 32/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 33/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.449%
# Epoch 34/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 35/110, Training Loss: 5.311, Validation Loss: 5.300, Accuracy on test set: 0.518%
# Epoch 36/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 37/110, Training Loss: 5.312, Validation Loss: 5.299, Accuracy on test set: 0.259%
# Epoch 38/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.397%
# Epoch 39/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 40/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 41/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 42/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 43/110, Training Loss: 5.311, Validation Loss: 5.300, Accuracy on test set: 0.518%
# Epoch 44/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 45/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.501%
# Epoch 46/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.362%
# Epoch 47/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 48/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 49/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 50/110, Training Loss: 5.311, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 51/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 52/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 53/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 54/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 55/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 56/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 57/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 58/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 59/110, Training Loss: 5.300, Validation Loss: 5.299, Accuracy on test set: 0.518%
# Epoch 60/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 61/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 62/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 63/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 64/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.259%
# Epoch 65/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 66/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 67/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.397%
# Epoch 68/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 69/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.259%
# Epoch 70/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.259%
# Epoch 71/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.259%
# Epoch 72/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.259%
# Epoch 73/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 74/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 75/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 76/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 77/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 78/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 79/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 80/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 81/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 82/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 83/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 84/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 85/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 86/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 87/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 88/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 89/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 90/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 91/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 92/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 93/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 94/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 95/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 96/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 97/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 98/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.518%
# Epoch 99/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 100/110, Training Loss: 5.300, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 101/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 102/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 103/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 104/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 105/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 106/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 107/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 108/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 109/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%
# Epoch 110/110, Training Loss: 5.298, Validation Loss: 5.298, Accuracy on test set: 0.501%

# %%
# !tensorboard --logdir=runs
