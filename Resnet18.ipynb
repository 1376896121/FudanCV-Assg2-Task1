# %%
from cub2011 import *
from torchvision.models import resnet18, ResNet18_Weights
from torchvision import transforms
import torch.nn as nn
import torch

# Define the transform with augmentation
transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # 随机裁剪并调整大小
    transforms.RandomHorizontalFlip(),                    # 随机水平翻转
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 随机颜色抖动
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Define the transform
# transform = transforms.Compose([
#     transforms.Resize((224, 224)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
# ])

# load dataset
train = Cub2011("", transform=transform)
test = Cub2011("", train=False, transform=transform)

# see example data
# img, target = train.__getitem__(999)
# img.show()

# load resnet18
net = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
# net = resnet18()
net.fc = nn.Linear(512, 200)

# move the net to GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=200, bias=True)
# )

# %%
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import StepLR
from torch.utils.tensorboard import SummaryWriter


# Loss
criterion = nn.CrossEntropyLoss()

# Separate parameters into two groups
base_lr = 0.001
finetune_rate = 0.01
finetune_lr = finetune_rate * base_lr
params_to_update = [
    {'params': net.conv1.parameters(), 'lr': finetune_lr},
    {'params': net.layer1.parameters(), 'lr': finetune_lr},
    {'params': net.layer2.parameters(), 'lr': finetune_lr},
    {'params': net.layer3.parameters(), 'lr': finetune_lr},
    {'params': net.layer4.parameters(), 'lr': finetune_lr},
    {'params': net.fc.parameters(), 'lr': base_lr}  # The last layer
]

# optimizer
optimizer = optim.SGD(params_to_update, momentum=0.9, weight_decay=1e-4)

# Learning rate sechuler
scheduler = StepLR(optimizer, step_size=50, gamma=0.1)

train_loader = DataLoader(train, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test, batch_size=32, shuffle=False, num_workers=4)

# TENSORBOARD
writer = SummaryWriter(log_dir='Resnet18/resnet18-lre-3-ftrate-2')

# training loop
num_epochs = 110
for epoch in range(num_epochs):
    # train
    net.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    train_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.3f}", end=", ")
    
    # Write training loss to TensorBoard
    writer.add_scalar('Training Loss', train_loss, epoch)

    # validation
    net.eval()
    correct = 0
    total = 0
    running_loss = 0.0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to the device
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    val_loss = running_loss / len(test_loader)
    accuracy = 100 * correct / total
    print(f'Validation Loss: {val_loss:.3f}', end=", ")
    print(f'Accuracy on test set: {accuracy:.3f}%')

    # Write validation loss and accuracy to TensorBoard
    writer.add_scalar('Validation Loss', val_loss, epoch)
    writer.add_scalar('Accuracy', accuracy, epoch)

    # Update the learning rate
    scheduler.step()
    
# Close the TensorBoard writer
writer.close()
# Out:
# WARNING:tensorflow:From d:\Anaconda\envs\pytorch\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Epoch 1/110, Training Loss: 5.246, Validation Loss: 4.925, Accuracy on test set: 5.661%
# Epoch 2/110, Training Loss: 4.719, Validation Loss: 4.467, Accuracy on test set: 15.499%
# Epoch 3/110, Training Loss: 4.275, Validation Loss: 4.083, Accuracy on test set: 24.560%
# Epoch 4/110, Training Loss: 3.882, Validation Loss: 3.742, Accuracy on test set: 32.137%
# Epoch 5/110, Training Loss: 3.544, Validation Loss: 3.472, Accuracy on test set: 35.261%
# Epoch 6/110, Training Loss: 3.249, Validation Loss: 3.187, Accuracy on test set: 40.680%
# Epoch 7/110, Training Loss: 2.975, Validation Loss: 2.986, Accuracy on test set: 43.303%
# Epoch 8/110, Training Loss: 2.751, Validation Loss: 2.789, Accuracy on test set: 46.272%
# Epoch 9/110, Training Loss: 2.551, Validation Loss: 2.643, Accuracy on test set: 47.687%
# Epoch 10/110, Training Loss: 2.384, Validation Loss: 2.492, Accuracy on test set: 51.622%
# Epoch 11/110, Training Loss: 2.226, Validation Loss: 2.369, Accuracy on test set: 52.295%
# Epoch 12/110, Training Loss: 2.097, Validation Loss: 2.268, Accuracy on test set: 54.453%
# Epoch 13/110, Training Loss: 1.970, Validation Loss: 2.168, Accuracy on test set: 54.764%
# Epoch 14/110, Training Loss: 1.870, Validation Loss: 2.107, Accuracy on test set: 55.350%
# Epoch 15/110, Training Loss: 1.761, Validation Loss: 2.024, Accuracy on test set: 57.145%
# Epoch 16/110, Training Loss: 1.688, Validation Loss: 1.957, Accuracy on test set: 58.008%
# Epoch 17/110, Training Loss: 1.611, Validation Loss: 1.899, Accuracy on test set: 58.008%
# Epoch 18/110, Training Loss: 1.552, Validation Loss: 1.854, Accuracy on test set: 58.992%
# Epoch 19/110, Training Loss: 1.482, Validation Loss: 1.793, Accuracy on test set: 59.424%
# Epoch 20/110, Training Loss: 1.419, Validation Loss: 1.761, Accuracy on test set: 59.821%
# Epoch 21/110, Training Loss: 1.376, Validation Loss: 1.706, Accuracy on test set: 60.787%
# Epoch 22/110, Training Loss: 1.325, Validation Loss: 1.700, Accuracy on test set: 60.822%
# Epoch 23/110, Training Loss: 1.279, Validation Loss: 1.648, Accuracy on test set: 61.564%
# Epoch 24/110, Training Loss: 1.236, Validation Loss: 1.633, Accuracy on test set: 61.771%
# Epoch 25/110, Training Loss: 1.209, Validation Loss: 1.601, Accuracy on test set: 61.771%
# Epoch 26/110, Training Loss: 1.165, Validation Loss: 1.564, Accuracy on test set: 62.392%
# Epoch 27/110, Training Loss: 1.131, Validation Loss: 1.568, Accuracy on test set: 62.237%
# Epoch 28/110, Training Loss: 1.106, Validation Loss: 1.548, Accuracy on test set: 62.720%
# Epoch 29/110, Training Loss: 1.085, Validation Loss: 1.512, Accuracy on test set: 63.376%
# Epoch 30/110, Training Loss: 1.053, Validation Loss: 1.505, Accuracy on test set: 63.203%
# Epoch 31/110, Training Loss: 1.028, Validation Loss: 1.485, Accuracy on test set: 63.721%
# Epoch 32/110, Training Loss: 0.995, Validation Loss: 1.458, Accuracy on test set: 63.842%
# Epoch 33/110, Training Loss: 0.975, Validation Loss: 1.456, Accuracy on test set: 63.928%
# Epoch 34/110, Training Loss: 0.948, Validation Loss: 1.424, Accuracy on test set: 64.480%
# Epoch 35/110, Training Loss: 0.936, Validation Loss: 1.415, Accuracy on test set: 64.360%
# Epoch 36/110, Training Loss: 0.912, Validation Loss: 1.416, Accuracy on test set: 64.049%
# Epoch 37/110, Training Loss: 0.882, Validation Loss: 1.401, Accuracy on test set: 64.722%
# Epoch 38/110, Training Loss: 0.877, Validation Loss: 1.382, Accuracy on test set: 64.860%
# Epoch 39/110, Training Loss: 0.853, Validation Loss: 1.379, Accuracy on test set: 65.240%
# Epoch 40/110, Training Loss: 0.835, Validation Loss: 1.365, Accuracy on test set: 64.774%
# Epoch 41/110, Training Loss: 0.814, Validation Loss: 1.364, Accuracy on test set: 64.774%
# Epoch 42/110, Training Loss: 0.804, Validation Loss: 1.360, Accuracy on test set: 65.464%
# Epoch 43/110, Training Loss: 0.797, Validation Loss: 1.343, Accuracy on test set: 65.568%
# Epoch 44/110, Training Loss: 0.771, Validation Loss: 1.333, Accuracy on test set: 65.637%
# Epoch 45/110, Training Loss: 0.765, Validation Loss: 1.321, Accuracy on test set: 65.154%
# Epoch 46/110, Training Loss: 0.756, Validation Loss: 1.325, Accuracy on test set: 65.464%
# Epoch 47/110, Training Loss: 0.731, Validation Loss: 1.314, Accuracy on test set: 65.844%
# Epoch 48/110, Training Loss: 0.725, Validation Loss: 1.308, Accuracy on test set: 65.637%
# Epoch 49/110, Training Loss: 0.710, Validation Loss: 1.319, Accuracy on test set: 65.499%
# Epoch 50/110, Training Loss: 0.693, Validation Loss: 1.286, Accuracy on test set: 65.827%
# Epoch 51/110, Training Loss: 0.670, Validation Loss: 1.298, Accuracy on test set: 65.878%
# Epoch 52/110, Training Loss: 0.669, Validation Loss: 1.297, Accuracy on test set: 65.706%
# Epoch 53/110, Training Loss: 0.662, Validation Loss: 1.293, Accuracy on test set: 66.103%
# Epoch 54/110, Training Loss: 0.670, Validation Loss: 1.284, Accuracy on test set: 66.086%
# Epoch 55/110, Training Loss: 0.669, Validation Loss: 1.287, Accuracy on test set: 66.224%
# Epoch 56/110, Training Loss: 0.671, Validation Loss: 1.288, Accuracy on test set: 65.637%
# Epoch 57/110, Training Loss: 0.670, Validation Loss: 1.283, Accuracy on test set: 66.206%
# Epoch 58/110, Training Loss: 0.663, Validation Loss: 1.283, Accuracy on test set: 66.051%
# Epoch 59/110, Training Loss: 0.663, Validation Loss: 1.293, Accuracy on test set: 65.982%
# Epoch 60/110, Training Loss: 0.662, Validation Loss: 1.298, Accuracy on test set: 65.792%
# Epoch 61/110, Training Loss: 0.663, Validation Loss: 1.287, Accuracy on test set: 66.206%
# Epoch 62/110, Training Loss: 0.658, Validation Loss: 1.279, Accuracy on test set: 65.723%
# Epoch 63/110, Training Loss: 0.662, Validation Loss: 1.300, Accuracy on test set: 65.740%
# Epoch 64/110, Training Loss: 0.656, Validation Loss: 1.298, Accuracy on test set: 65.171%
# Epoch 65/110, Training Loss: 0.657, Validation Loss: 1.288, Accuracy on test set: 65.585%
# Epoch 66/110, Training Loss: 0.653, Validation Loss: 1.295, Accuracy on test set: 66.017%
# Epoch 67/110, Training Loss: 0.654, Validation Loss: 1.280, Accuracy on test set: 66.034%
# Epoch 68/110, Training Loss: 0.652, Validation Loss: 1.284, Accuracy on test set: 66.362%
# Epoch 69/110, Training Loss: 0.650, Validation Loss: 1.280, Accuracy on test set: 65.896%
# Epoch 70/110, Training Loss: 0.652, Validation Loss: 1.281, Accuracy on test set: 66.172%
# Epoch 71/110, Training Loss: 0.645, Validation Loss: 1.284, Accuracy on test set: 66.293%
# Epoch 72/110, Training Loss: 0.651, Validation Loss: 1.282, Accuracy on test set: 66.483%
# Epoch 73/110, Training Loss: 0.644, Validation Loss: 1.295, Accuracy on test set: 66.586%
# Epoch 74/110, Training Loss: 0.649, Validation Loss: 1.280, Accuracy on test set: 66.120%
# Epoch 75/110, Training Loss: 0.648, Validation Loss: 1.287, Accuracy on test set: 65.999%
# Epoch 76/110, Training Loss: 0.643, Validation Loss: 1.282, Accuracy on test set: 66.017%
# Epoch 77/110, Training Loss: 0.647, Validation Loss: 1.277, Accuracy on test set: 66.068%
# Epoch 78/110, Training Loss: 0.648, Validation Loss: 1.281, Accuracy on test set: 66.483%
# Epoch 79/110, Training Loss: 0.641, Validation Loss: 1.283, Accuracy on test set: 65.378%
# Epoch 80/110, Training Loss: 0.641, Validation Loss: 1.283, Accuracy on test set: 66.086%
# Epoch 81/110, Training Loss: 0.643, Validation Loss: 1.283, Accuracy on test set: 65.844%
# Epoch 82/110, Training Loss: 0.636, Validation Loss: 1.290, Accuracy on test set: 65.809%
# Epoch 83/110, Training Loss: 0.644, Validation Loss: 1.276, Accuracy on test set: 66.189%
# Epoch 84/110, Training Loss: 0.631, Validation Loss: 1.282, Accuracy on test set: 66.137%
# Epoch 85/110, Training Loss: 0.639, Validation Loss: 1.262, Accuracy on test set: 66.914%
# Epoch 86/110, Training Loss: 0.634, Validation Loss: 1.269, Accuracy on test set: 66.189%
# Epoch 87/110, Training Loss: 0.633, Validation Loss: 1.274, Accuracy on test set: 66.362%
# Epoch 88/110, Training Loss: 0.629, Validation Loss: 1.287, Accuracy on test set: 65.948%
# Epoch 89/110, Training Loss: 0.634, Validation Loss: 1.275, Accuracy on test set: 66.327%
# Epoch 90/110, Training Loss: 0.631, Validation Loss: 1.281, Accuracy on test set: 65.792%
# Epoch 91/110, Training Loss: 0.631, Validation Loss: 1.272, Accuracy on test set: 66.344%
# Epoch 92/110, Training Loss: 0.634, Validation Loss: 1.277, Accuracy on test set: 65.913%
# Epoch 93/110, Training Loss: 0.631, Validation Loss: 1.284, Accuracy on test set: 66.103%
# Epoch 94/110, Training Loss: 0.631, Validation Loss: 1.275, Accuracy on test set: 66.431%
# Epoch 95/110, Training Loss: 0.629, Validation Loss: 1.270, Accuracy on test set: 65.758%
# Epoch 96/110, Training Loss: 0.629, Validation Loss: 1.270, Accuracy on test set: 66.344%
# Epoch 97/110, Training Loss: 0.633, Validation Loss: 1.276, Accuracy on test set: 66.793%
# Epoch 98/110, Training Loss: 0.621, Validation Loss: 1.272, Accuracy on test set: 66.448%
# Epoch 99/110, Training Loss: 0.623, Validation Loss: 1.272, Accuracy on test set: 66.241%
# Epoch 100/110, Training Loss: 0.611, Validation Loss: 1.273, Accuracy on test set: 66.293%
# Epoch 101/110, Training Loss: 0.609, Validation Loss: 1.278, Accuracy on test set: 66.603%
# Epoch 102/110, Training Loss: 0.625, Validation Loss: 1.267, Accuracy on test set: 66.379%
# Epoch 103/110, Training Loss: 0.615, Validation Loss: 1.267, Accuracy on test set: 66.431%
# Epoch 104/110, Training Loss: 0.616, Validation Loss: 1.268, Accuracy on test set: 65.844%
# Epoch 105/110, Training Loss: 0.623, Validation Loss: 1.260, Accuracy on test set: 66.465%
# Epoch 106/110, Training Loss: 0.613, Validation Loss: 1.262, Accuracy on test set: 67.000%
# Epoch 107/110, Training Loss: 0.623, Validation Loss: 1.268, Accuracy on test set: 66.534%
# Epoch 108/110, Training Loss: 0.617, Validation Loss: 1.263, Accuracy on test set: 65.740%
# Epoch 109/110, Training Loss: 0.626, Validation Loss: 1.263, Accuracy on test set: 66.500%
# Epoch 110/110, Training Loss: 0.617, Validation Loss: 1.271, Accuracy on test set: 66.552%

# %%
# !tensorboard --logdir=runs
